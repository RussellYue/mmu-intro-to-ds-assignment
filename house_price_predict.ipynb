# %% [markdown]
# # PART B

# %% [markdown]
# ## Context
#
# In part A, we set the context by giving the example of two compnies that applied data science to further its growth. Our main focus was Recommendation Systems and Price Optimisation. In this part, we will concretely apply one of these techniques to solve a business problem and to answer questions that could help us better improve the operation of the business.
# In this part, we would like to explore an implementation of a Price Optimisation model, that works by predicting a sale price from the given parameters

# %% [markdown]
# ## Questions
#
# The problem we are faced with is trying to figure out what price tag to put on a given house or real estate property, given a set of parameters that describe this piece of real estate.
# So, this problem poses a central question:
#
# #### What is the best possible price for a given piece of real estate?
#
# This central question in turn will lead us to ask a few more related questions:
#
# - What are the factors that most influence the price of real estate?
# - How many features do we need to have to be able to calculate an accurate estimatin of the best sale price?
# - How can we judge if the given price is truly the best possible price?
#
# These questions will require data to answer. We will take a dataset that is relevant to the central problems and probe that data, then mine it for information. We will try to build a model that will answer our central question whenever we need to.

# %%
import warnings
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats
from scipy.stats import norm, skew
from sklearn import preprocessing
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNetCV, ElasticNet
from xgboost import XGBRegressor, plot_importance 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
# %matplotlib inline

pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

# %%
df = pd.read_csv('train.csv')
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# The dataset is from Kaggle. This is the link to the source: [Kaggle Dataset](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data)

# %%
(df.isnull().sum() / len(df)).sort_values(ascending=False)[:20]
# Out:
# PoolQC         0.995
# MiscFeature    0.963
# Alley          0.938
# Fence          0.808
# FireplaceQu    0.473
# LotFrontage    0.177
# GarageCond     0.055
# GarageType     0.055
# GarageYrBlt    0.055
# GarageFinish   0.055
# GarageQual     0.055
# BsmtExposure   0.026
# BsmtFinType2   0.026
# BsmtFinType1   0.025
# BsmtCond       0.025
# BsmtQual       0.025
# MasVnrArea     0.005
# MasVnrType     0.005
# Electrical     0.001
# Utilities      0.000
# dtype: float64

# %% [markdown]
# The good news is that we have many features to play with (81), the bad news is that 19 features have missing values, and 4 of them have over 80% missing values. For any feature, if it is missing 80% of values, it can’t be that important, therefore, I decided to remove these 4 features.

# %%
df.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'Id'], axis=1, inplace=True)

# %% [markdown]
# ## Explore Features

# %% [markdown]
# ### Target feature distribution

# %%
sns.distplot(df['SalePrice'] , fit=norm);
# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(df['SalePrice'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Sale Price distribution')
#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(df['SalePrice'], plot=plt)
plt.show();
# Out:
#  mu = 180921.20 and sigma = 79415.29

# %% [markdown]
# The target feature - SalePrice is right skewed. Because linear models work best with normally distributed data , we will transform SalePrice and make it more normally distributed.

# %%
sns.distplot(np.log1p(df['SalePrice']) , fit=norm);
# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(np.log1p(df['SalePrice']))
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('log(Sale Price+1) distribution')
#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(np.log1p(df['SalePrice']), plot=plt)
plt.show();
# Out:
#  mu = 12.02 and sigma = 0.40

# %% [markdown]
# ### Correlation between numeric features

# %%
pd.set_option('precision',2)
plt.figure(figsize=(10, 8))
sns.heatmap(df.drop(['SalePrice'],axis=1).corr(), square=True)
plt.suptitle("Pearson Correlation Heatmap")
plt.show();

# %% [markdown]
# There exists strong correlations between some of the features. For example, GarageYrBlt and YearBuilt, TotRmsAbvGrd and GrLivArea, GarageArea and GarageCars are strongly correlated. They actually express more or less the same thing. I will let ElasticNetCV to help reduce redundancy later.

# %% [markdown]
# ### Correlation between SalePrice and the other numeric features

# %%
corr_with_sale_price = df.corr()["SalePrice"].sort_values(ascending=False)
plt.figure(figsize=(14,6))
corr_with_sale_price.drop("SalePrice").plot.bar()
plt.show();

# %% [markdown]
# The correlation of SalePrice with OverallQual is the greatest (around 0.8). Also GrLivArea presents a correlation of over 0.7, and GarageCars presents a correlation of over 0.6. Let’s look at these 4 features in more detail.

# %%
sns.pairplot(df[['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars']])
plt.show();

# %% [markdown]
# ## Feature Engineering
# - Log transform features that have a highly skewed distribution (skew > 0.75)
# - Dummy coding categorical features
# - Fill NaN with the mean of the column.
# - Train and test sets split.

# %%
df["SalePrice"] = np.log1p(df["SalePrice"])

#log transform skewed numeric features:
numeric_feats = df.dtypes[df.dtypes != "object"].index

skewed_feats = df[numeric_feats].apply(lambda x: skew(x.dropna())) #compute skewness
skewed_feats = skewed_feats[skewed_feats > 0.75]
skewed_feats = skewed_feats.index

df[skewed_feats] = np.log1p(df[skewed_feats])
df = pd.get_dummies(df)
df = df.fillna(df.mean())

X, y = df.drop(['SalePrice'], axis = 1), df['SalePrice']
X_train, X_test, y_train, y_test  = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## ElasticNet
# - Ridge and Lasso regression are regularized linear regression models.
# - ElasticNet is useful when there are multiple features which are correlated with one another.
# - The class ElasticNetCV can be used to set the parameters alpha (α) and l1_ratio (ρ) by cross-validation.
# - ElasticNetCV: ElasticNet model with best model selection by cross-validation.
#
# Let’s see what ElasticNetCV is going to select for us.

# %%
cv_model = ElasticNetCV(l1_ratio=[.1, .5, .7, .9, .95, .99, 1], eps=1e-3, n_alphas=100, fit_intercept=True, 
                        normalize=True, precompute='auto', max_iter=2000, tol=0.0001, cv=6, 
                        copy_X=True, verbose=0, n_jobs=-1, positive=False, random_state=0)
               
cv_model.fit(X_train, y_train)
print('Optimal alpha: %.8f'%cv_model.alpha_)
print('Optimal l1_ratio: %.3f'%cv_model.l1_ratio_)
print('Number of iterations %d'%cv_model.n_iter_)
# Out:
# Optimal alpha: 0.00013634
# Optimal l1_ratio: 0.700
# Number of iterations 84

# %% [markdown]
# 0< The optimal l1_ratio <1 , indicating the penalty is a combination of L1 and L2, that is, the combination of Lasso and Ridge.

# %% [markdown]
# ### ElasticNet Model Evaluation

# %%
y_train_pred = cv_model.predict(X_train)
y_pred = cv_model.predict(X_test)
print('Train r2 score: ', r2_score(y_train_pred, y_train))
print('Test r2 score: ', r2_score(y_test, y_pred))
train_mse = mean_squared_error(y_train_pred, y_train)
test_mse = mean_squared_error(y_pred, y_test)
train_rmse = np.sqrt(train_mse)
test_rmse = np.sqrt(test_mse)
print('Train RMSE: %.4f' % train_rmse)
print('Test RMSE: %.4f' % test_rmse)
# Out:
# Train r2 score:  0.935231601879496
# Test r2 score:  0.8300355301028952
# Train RMSE: 0.0963
# Test RMSE: 0.1604

# %% [markdown]
# The RMSE here is actually RMSLE ( Root Mean Squared Logarithmic Error). Because we have taken the log of the actual values.

# %% [markdown]
# ### Feature Importance

# %%
feature_importance = pd.Series(index = X_train.columns, data = np.abs(cv_model.coef_))
n_selected_features = (feature_importance>0).sum()
print('{0:d} features, reduction of {1:2.2f}%'.format(
    n_selected_features,(1-n_selected_features/len(feature_importance))*100))
feature_importance.sort_values().tail(30).plot(kind = 'bar', figsize = (12,5));
# Out:
# 113 features, reduction of 58.91%

# %% [markdown]
# A reduction of 58.91% features looks productive. The top 4 most important features selected by ElasticNetCV are Condition2_PosN, MSZoning_C(all), Exterior1st_BrkComm & GrLivArea. We are going to see how these features compare with those selected by Xgboost.

# %% [markdown]
# ## Xgboost

# %% [markdown]
# ## First
# The first Xgboost model, we start from default parameters.

# %%
xgb_model1 = XGBRegressor()
xgb_model1.fit(X_train, y_train, verbose=False)
y_train_pred1 = xgb_model1.predict(X_train)
y_pred1 = xgb_model1.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
print('Train r2 score: ', r2_score(y_train_pred1, y_train))
print('Test r2 score: ', r2_score(y_test, y_pred1))
train_mse1 = mean_squared_error(y_train_pred1, y_train)
test_mse1 = mean_squared_error(y_pred1, y_test)
train_rmse1 = np.sqrt(train_mse1)
test_rmse1 = np.sqrt(test_mse1)
print('Train RMSE: %.4f' % train_rmse1)
print('Test RMSE: %.4f' % test_rmse1)
# Out:
# Train r2 score:  0.9546691336034475
# Test r2 score:  0.8856612816972917
# Train RMSE: 0.0820
# Test RMSE: 0.1316

# %% [markdown]
# It is already way better than the model selected by ElasticNetCV.
#
# The second Xgboost model, we gradually add a few parameters that suppose to add model’s accuracy.

# %% [markdown]
# ## Second

# %%
xgb_model2 = XGBRegressor(n_estimators=1000)
xgb_model2.fit(X_train, y_train, early_stopping_rounds=5, 
             eval_set=[(X_test, y_test)], verbose=False)
y_train_pred2 = xgb_model2.predict(X_train)
y_pred2 = xgb_model2.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
print('Train r2 score: ', r2_score(y_train_pred2, y_train))
print('Test r2 score: ', r2_score(y_test, y_pred2))
train_mse2 = mean_squared_error(y_train_pred2, y_train)
test_mse2 = mean_squared_error(y_pred2, y_test)
train_rmse2 = np.sqrt(train_mse2)
test_rmse2 = np.sqrt(test_mse2)
print('Train RMSE: %.4f' % train_rmse2)
print('Test RMSE: %.4f' % test_rmse2)
# Out:
# Train r2 score:  0.9678837547788781
# Test r2 score:  0.8931330796873692
# Train RMSE: 0.0699
# Test RMSE: 0.1272

# %% [markdown]
# There was again an improvement.
#
# The third Xgboost model, we add a learning rate, hopefully it will yield a more accurate model.

# %% [markdown]
# ## Third

# %%
xgb_model3 = XGBRegressor(n_estimators=1000, learning_rate=0.05)
xgb_model3.fit(X_train, y_train, early_stopping_rounds=5, 
             eval_set=[(X_test, y_test)], verbose=False)
y_train_pred3 = xgb_model3.predict(X_train)
y_pred3 = xgb_model3.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
print('Train r2 score: ', r2_score(y_train_pred3, y_train))
print('Test r2 score: ', r2_score(y_test, y_pred3))
train_mse3 = mean_squared_error(y_train_pred3, y_train)
test_mse3 = mean_squared_error(y_pred3, y_test)
train_rmse3 = np.sqrt(train_mse3)
test_rmse3 = np.sqrt(test_mse3)
print('Train RMSE: %.4f' % train_rmse3)
print('Test RMSE: %.4f' % test_rmse3)
# Out:
# Train r2 score:  0.9479569687487649
# Test r2 score:  0.8840040768045745
# Train RMSE: 0.0869
# Test RMSE: 0.1325

# %% [markdown]
# Unfortunately, there was no improvement. I concluded that **xgb_model2** is the best model.

# %% [markdown]
# ### Feature Importance

# %%
from collections import OrderedDict
OrderedDict(sorted(xgb_model2.get_booster().get_fscore().items(), key=lambda t: t[1], reverse=True))
# Out:
# OrderedDict([('LotArea', 68),
#              ('GrLivArea', 64),
#              ('OverallQual', 56),
#              ('TotalBsmtSF', 45),
#              ('OverallCond', 45),
#              ('GarageYrBlt', 33),
#              ('BsmtUnfSF', 30),
#              ('LotFrontage', 29),
#              ('YearRemodAdd', 27),
#              ('BsmtFinSF1', 26),
#              ('YearBuilt', 24),
#              ('MSSubClass', 24),
#              ('GarageArea', 23),
#              ('MoSold', 20),
#              ('2ndFlrSF', 19),
#              ('1stFlrSF', 18),
#              ('OpenPorchSF', 17),
#              ('MSZoning_C (all)', 16),
#              ('EnclosedPorch', 15),
#              ('Functional_Typ', 14),
#              ('SaleCondition_Abnorml', 13),
#              ('Condition1_Norm', 12),
#              ('WoodDeckSF', 11),
#              ('Neighborhood_Crawfor', 11),
#              ('ScreenPorch', 11),
#              ('PoolArea', 11),
#              ('MasVnrArea', 10),
#              ('KitchenAbvGr', 8),
#              ('Condition1_Artery', 8),
#              ('Exterior1st_BrkFace', 8),
#              ('MSZoning_FV', 8),
#              ('CentralAir_N', 7),
#              ('BedroomAbvGr', 7),
#              ('Neighborhood_BrkSide', 7),
#              ('Fireplaces', 6),
#              ('BsmtFullBath', 6),
#              ('SaleType_New', 6),
#              ('YrSold', 6),
#              ('BsmtFinSF2', 6),
#              ('GarageCars', 5),
#              ('KitchenQual_Ex', 5),
#              ('BsmtExposure_Gd', 5),
#              ('LotShape_Reg', 5),
#              ('Neighborhood_Mitchel', 5),
#              ('BsmtQual_Gd', 5),
#              ('Neighborhood_ClearCr', 5),
#              ('Neighborhood_Edwards', 5),
#              ('BsmtFinType1_ALQ', 5),
#              ('BsmtFinType1_Rec', 5),
#              ('GarageType_Attchd', 4),
#              ('GarageFinish_Unf', 4),
#              ('MasVnrType_BrkFace', 4),
#              ('BsmtExposure_No', 4),
#              ('FullBath', 4),
#              ('BsmtHalfBath', 4),
#              ('Exterior1st_AsbShng', 4),
#              ('RoofStyle_Gable', 4),
#              ('LotConfig_CulDSac', 4),
#              ('Foundation_BrkTil', 4),
#              ('FireplaceQu_Po', 4),
#              ('Exterior1st_BrkComm', 3),
#              ('MSZoning_RL', 3),
#              ('BsmtFinType1_GLQ', 3),
#              ('GarageQual_TA', 3),
#              ('HalfBath', 3),
#              ('HeatingQC_Fa', 3),
#              ('Exterior2nd_Wd Shng', 3),
#              ('Condition1_PosN', 3),
#              ('RoofMatl_WdShngl', 3),
#              ('LotShape_IR1', 3),
#              ('MSZoning_RM', 2),
#              ('BsmtQual_Ex', 2),
#              ('GarageType_Detchd', 2),
#              ('Neighborhood_Sawyer', 2),
#              ('Condition1_PosA', 2),
#              ('Neighborhood_OldTown', 2),
#              ('Neighborhood_NAmes', 2),
#              ('Condition2_Norm', 2),
#              ('Exterior1st_VinylSd', 2),
#              ('MSZoning_RH', 2),
#              ('FireplaceQu_TA', 2),
#              ('MasVnrType_BrkCmn', 2),
#              ('Neighborhood_NWAmes', 2),
#              ('SaleType_COD', 2),
#              ('LandContour_Low', 2),
#              ('BsmtFinType1_LwQ', 2),
#              ('Exterior1st_HdBoard', 2),
#              ('Exterior1st_Wd Sdng', 2),
#              ('BsmtFinType1_BLQ', 2),
#              ('Exterior1st_MetalSd', 2),
#              ('BsmtQual_Fa', 2),
#              ('LotConfig_FR2', 2),
#              ('Condition1_RRAe', 2),
#              ('BsmtFinType2_BLQ', 2),
#              ('Functional_Maj2', 1),
#              ('Heating_Grav', 1),
#              ('GarageCond_TA', 1),
#              ('PavedDrive_P', 1),
#              ('PavedDrive_Y', 1),
#              ('Functional_Min1', 1),
#              ('MasVnrType_Stone', 1),
#              ('HeatingQC_TA', 1),
#              ('RoofStyle_Flat', 1),
#              ('SaleCondition_Family', 1),
#              ('ExterCond_Fa', 1),
#              ('GarageQual_Fa', 1),
#              ('GarageFinish_RFn', 1),
#              ('BsmtCond_TA', 1),
#              ('BldgType_Duplex', 1),
#              ('BsmtQual_TA', 1),
#              ('LotConfig_Inside', 1),
#              ('LowQualFinSF', 1),
#              ('SaleCondition_Normal', 1),
#              ('LandContour_HLS', 1),
#              ('GarageType_2Types', 1),
#              ('GarageFinish_Fin', 1),
#              ('BsmtCond_Fa', 1),
#              ('Exterior1st_CemntBd', 1)])

# %% [markdown]
# The top 4 most important features selected by Xgboost are LotArea, GrLivArea, OverallQual & TotalBsmtSF.
#
# There is only one feature GrLivArea was selected by both ElasticNetCV and Xgboost.
#
# So now we are going to select some relevant features and fit the Xgboost again.

# %%
most_relevant_features= list( dict((k, v) for k, v in xgb_model2.get_booster().get_fscore().items() if v >= 4).keys())
train_x=df[most_relevant_features]
train_y=df['SalePrice']
X_train, X_test, y_train, y_test  = train_test_split(train_x, train_y, test_size = 0.2, random_state = 0)
xgb_model5 = XGBRegressor(n_estimators=1000)
xgb_model5.fit(X_train, y_train, early_stopping_rounds=5, 
             eval_set=[(X_test, y_test)], verbose=False)
y_train_pred5 = xgb_model5.predict(X_train)
y_pred5 = xgb_model5.predict(X_test)

print('Train r2 score: ', r2_score(y_train_pred5, y_train))
print('Test r2 score: ', r2_score(y_test, y_pred5))
train_mse5 = mean_squared_error(y_train_pred5, y_train)
test_mse5 = mean_squared_error(y_pred5, y_test)
train_rmse5 = np.sqrt(train_mse5)
test_rmse5 = np.sqrt(test_mse5)
print('Train RMSE: %.4f' % train_rmse5)
print('Test RMSE: %.4f' % test_rmse5)
# Out:
# Train r2 score:  0.9585238274804593
# Test r2 score:  0.8950051742272032
# Train RMSE: 0.0787
# Test RMSE: 0.1261

# %% [markdown]
# Another small improvement.

# %% [markdown]
# ## Conclusion
#
# We have thus created a model that predicts the price of a real estate by its given parmeters. It tries to approximaet the price as much as possible to answer the central question of the problem. It also answers more descriptive questions about the data needed, the types and amount of features needed, and the features that most affect the price.
